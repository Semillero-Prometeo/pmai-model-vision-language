# %%
pip install beautifulsoup4
# Out:
# /Users/anpalop/Desktop/Universidad/pmai-model-vision-language/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.
